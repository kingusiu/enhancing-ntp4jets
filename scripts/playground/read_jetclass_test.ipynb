# %%
import uproot
import glob
import sys

# %%
data_dir = '/srv/beegfs/scratch/groups/rodem/lumea/datasets/JetClass/Pythia/train_100M'
files = sorted(glob.glob(f'{data_dir}/*.root'))[:5]
print(f'Checking {len(files)} files...')
# Out:
# Checking 5 files...

# %%
ff = uproot.open(files[0])
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ff = uproot.open(files[0])
#
# File /opt/conda/lib/python3.11/site-packages/uproot/reading.py:154, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     143 file = ReadOnlyFile(
#     144     file_path,
#     145     object_cache=object_cache,
#    (...)
#     150     **options,  # NOTE: a comma after **options breaks Python 2
#     151 )
#     153 if object_path is None:
# --> 154     return file.root_directory
#     155 else:
#     156     return file.root_directory[object_path]
#
# File /opt/conda/lib/python3.11/site-packages/uproot/reading.py:789, in ReadOnlyFile.root_directory(self)
#     783 @property
#     784 def root_directory(self):
#     785     """
#     786     The root ``TDirectory`` of the file
# ...
